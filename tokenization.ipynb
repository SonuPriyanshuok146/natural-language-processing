# %%
# !pip install nltk

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python311\python.exe

# %%
import sys
!"{sys.executable}" -m pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for nltk from https://files.pythonhosted.org/packages/9d/91/04e965f8e717ba0ab4bdca5c112deeab11c9e750d94c4d4602f050295d39/nltk-3.9.4-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/fb/e2/79c688af8b210d232694e31e59da9f6ec747bae31c3f5946e4e9b98860d5/click-8.4.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/7b/91/984aca2ec129e2757d1e4e3c81c3fcda9d0f85b74670a094cc443d9ee949/joblib-1.5.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/c6/cf/a48d8e8d406b22481cad146f48fa0dfca3c5f402b91f26d8e5a0fe4f513d/regex-2026.6.28-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
# ...

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.9.4

# %%
## TOkenization
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sonup\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
corpus = """Hello welcome to Yoga World where balancing yourself is key. Keep yourself free from Imaginary world."""

# %%
corpus
# Out:
# 'Hello welcome to Yoga World where balancing yourself is key. Keep yourself free from Imaginary world.'

# %%
from nltk.tokenize import sent_tokenize
# from nltk.tokenize import word_tokenize


documents=sent_tokenize(corpus)
# word_tokenize(corpus)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[23], line 5
#       1 from nltk.tokenize import sent_tokenize
#       2 # from nltk.tokenize import word_tokenize
#       3
#       4
# ----> 5 documents=sent_tokenize(corpus)
#       6 # word_tokenize(corpus)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# ...

# %%
type(documents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 type(documents)
#
# NameError: name 'documents' is not defined

# %%
for sentence in documents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 for sentence in documents:
#       2     print(sentence)
#
# NameError: name 'documents' is not defined

# %%
## Tokenization
## paragraph into word
##sentence into word

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 word_tokenize(corpus)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
# ...

# %%
import nltk
nltk.download('punkt', download_dir='c:/users/sonup/appdata/roaming/python/python311')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     c:/users/sonup/appdata/roaming/python/python311...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# C:\Users\sonup\AppData\Roaming\Python\Python311\site-packages\nltk\downloader.py:2395: RuntimeWarning: Security Violation [pathsec.ZipFile]: Unauthorized path C:\Users\sonup\AppData\Roaming\Python\Python311\tokenizers\punkt.zip
#   zf = ZipFile(filename)
# True

# %%
import nltk
nltk.download('punkt', download_dir='c:/users/sonup/appdata/roaming/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     c:/users/sonup/appdata/roaming/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'Yoga',
#  'World',
#  'where',
#  'balancing',
#  'yourself',
#  'is',
#  'key.',
#  'Keep',
#  'yourself',
#  'free',
#  'from',
#  'Imaginary',
#  'world',
#  '.']
